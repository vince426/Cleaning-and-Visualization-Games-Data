# %% [markdown]
# ### Quick Visualizations in Games
#
# Analyze using visualizations in matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
games = pd.read_csv('cleaned_games.csv', parse_dates=['Release Date'])

# %% [markdown]
# ### The Data at Glance

# %%
games.head()
# Out:
#                                      Title Release Date  \
# 0                               Elden Ring   2022-02-25
# 1                                    Hades   2019-12-10
# 2  The Legend of Zelda: Breath of the Wild   2017-03-03
# 3                                Undertale   2015-09-15
# 4                            Hollow Knight   2017-02-24
#
#                                             Team  Rating  \
# 0       Bandai Namco Entertainment, FromSoftware     4.5
# 1                               Supergiant Games     4.3
# 2  Nintendo, Nintendo EPD Production Group No. 3     4.4
# 3                                   tobyfox, 8-4     4.2
# 4                                    Team Cherry     4.4
#
#                                              Summary    Genre 1   Genre 2  \
# 0  Elden Ring is a fantasy, action and open world...  Adventure       RPG
# 1  A rogue-lite hack and slash dungeon crawler in...  Adventure   Brawler
# ...

# %%
games.shape
# it shows how many rows and columns we have
# Out:
# (1096, 12)

# %%
games.info()
# checking if our data types are correct especially the Release Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    1096 non-null   object
#  1   Release Date             1096 non-null   datetime64[ns]
#  2   Team                     1095 non-null   object
#  3   Rating                   1084 non-null   float64
#  4   Summary                  1096 non-null   object
#  5   Genre 1                  1093 non-null   object
#  6   Genre 2                  866 non-null    object
#  7   Times Listed Clean       1096 non-null   int64
#  8   Number of Reviews Clean  1096 non-null   int64
#  9   Plays Clean              1096 non-null   int64
#  10  Backlogs Clean           1096 non-null   int64
#  11  Wishlist Clean           1096 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(5)
# memory usage: 102.9+ KB

# %%
games['Release Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1096 entries, 0 to 1095
# Series name: Release Date
# Non-Null Count  Dtype
# --------------  -----
# 1096 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 8.7 KB

# %% [markdown]
# ### Genre Analysis
#
# Let's see what's the most popular genre 1 and genre 2

# %%
games['Genre 1'].value_counts()
# Out:
# Genre 1
# Adventure             710
# RPG                    77
# Shooter                58
# Arcade                 43
# Fighting               37
# Indie                  37
# Platform               34
# Brawler                26
# Racing                 14
# Card & Board Game      12
# Simulator              12
# Puzzle                  9
# Sport                   7
# Music                   6
# Point-and-Click         3
# Real Time Strategy      3
# MOBA                    2
# Visual Novel            2
# Strategy                1
# Name: count, dtype: int64

# %%
games['Genre 1'].value_counts().plot(kind='bar', figsize=(6,6))
# Out:
# <Axes: xlabel='Genre 1'>

# %%
# there is no much distribution with genre 1
games['Genre 2'].value_counts()
# Out:
# Genre 2
#  RPG                    193
#  Indie                  143
#  Platform               137
#  Shooter                 96
#  Brawler                 78
#  Puzzle                  41
#  Strategy                37
#  Simulator               24
#  Point-and-Click         20
#  Fighting                20
#  Racing                  17
#  Arcade                  17
#  Visual Novel            14
#  Real Time Strategy       6
#  Turn Based Strategy      6
#  Sport                    5
#  Tactical                 5
#  Music                    5
#  Card & Board Game        1
#  Quiz/Trivia              1
# Name: count, dtype: int64

# %%
games['Genre 2'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
games['Genre 2'].value_counts().plot(kind='bar', figsize=(6,6))
# Out:
# <Axes: xlabel='Genre 2'>

# %% [markdown]
# ### Distribution of Ratings

# %%
ratings_sorted = games.sort_values(by='Rating', ascending=False)
ratings_sorted.head(20)
# Out:
#                                            Title Release Date  \
# 808   Metal Gear Solid 3: Snake Eater HD Edition   2011-11-08
# 248                 Umineko: When They Cry Chiru   2009-09-15
# 621              Metal Gear Solid 3: Subsistence   2005-12-22
# 685            Final Fantasy XIV: Shadowbringers   2019-07-02
# 485                Hitman World of Assassination   2023-01-26
# 702            The Great Ace Attorney 2: Resolve   2017-08-03
# 716     Sekiro: Shadows Die Twice - GOTY Edition   2020-10-28
# 749                              Half-Life: Alyx   2020-03-23
# 763                               Dwarf Fortress   2022-12-06
# 43                                   Outer Wilds   2019-05-28
# 138                                Disco Elysium   2019-10-15
# 293                  Bloodborne: The Old Hunters   2015-11-24
# 873                                  Tokyo Necro   2016-01-29
# 28                  Disco Elysium: The Final Cut   2020-05-01
# ...

# %%
ratings = games['Rating']
game_names = games['Title']

# %% [markdown]
# ### Release Date
#
# by Year

# %%
games['Release Date'] = pd.to_datetime(games['Release Date'])

# %%
games['Year Released'] = games['Release Date'].dt.year

# %%
yearly_counts = games.groupby('Year Released').size()

# %%
plt.figure(figsize=(16,9))
plt.plot(yearly_counts.index, yearly_counts)
plt.xlabel('Year')
plt.ylabel('Number of Games Released')
plt.title('Game Releases by Year')
plt.xticks(yearly_counts.index[::2])
plt.show()

# %% [markdown]
# ### Wishlist vs Backlogs
#
# using scatterplot

# %%
games.plot(kind='scatter', x='Wishlist Clean', y='Backlogs Clean', figsize=(6,6))
# Out:
# <Axes: xlabel='Wishlist Clean', ylabel='Backlogs Clean'>

# %% [markdown]
# ### Rating vs Plays
#
# Correlation using scatterplot

# %%
games.plot(kind='scatter', x='Rating', y='Plays Clean', figsize=(6,6))
# Out:
# <Axes: xlabel='Rating', ylabel='Plays Clean'>

# %%
ratings_and_plays = games.sort_values(by=['Rating', 'Plays Clean'], ascending=[False, False])

# %%
ratings_and_plays[['Title', 'Rating', 'Plays Clean']].head(50)
# Out:
#                                                   Title  Rating  Plays Clean
# 43                                          Outer Wilds     4.6         7700
# 28                         Disco Elysium: The Final Cut     4.6         6000
# 293                         Bloodborne: The Old Hunters     4.6         4400
# 138                                       Disco Elysium     4.6         4000
# 621                     Metal Gear Solid 3: Subsistence     4.6         3700
# 685                   Final Fantasy XIV: Shadowbringers     4.6         3000
# 592                        Final Fantasy XIV: Endwalker     4.6         2500
# 808          Metal Gear Solid 3: Snake Eater HD Edition     4.6         2500
# 749                                     Half-Life: Alyx     4.6         1900
# 248                        Umineko: When They Cry Chiru     4.6         1700
# 909                Bloodborne: Game of the Year Edition     4.6         1500
# ...
